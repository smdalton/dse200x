# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = 'Qd8CwCKYlmwmdSYPWt12cR0XH'
    Twitter['Consumer Secret'] = '54QQkxSkDzuOXELanSHciVwN9KneMJ3whLxpmQ1HbhmrtCAgtZ'
    Twitter['Access Token'] = '23473757-5W2sEsIukSXz2NhRcIx90SVJ261WsjzqAy8IDdbKT'
    Twitter['Access Token Secret'] = 'SyyOAmF3mGpnNAeDMvumwDF0v0jQZ3Gov6odUh3ytmVT7'
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 432kB/s ta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x10e5d0588>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': 'Zion',
#     'url': 'http://twitter.com/search?q=Zion',
#     'promoted_content': None,
#     'query': 'Zion',
#     'tweet_volume': 89427},
#    {'name': '#LaLlamada',
#     'url': 'http://twitter.com/search?q=%23LaLlamada',
#     'promoted_content': None,
#     'query': '%23LaLlamada',
#     'tweet_volume': None},
#    {'name': '#iHeartAwards2019',
#     'url': 'http://twitter.com/search?q=%23iHeartAwards2019',
#     'promoted_content': None,
#     'query': '%23iHeartAwards2019',
#     'tweet_volume': 363427},
#    {'name': 'Christchurch',
#     'url': 'http://twitter.com/search?q=Christchurch',
#     'promoted_content': None,
#     'query': 'Christchurch',
#     'tweet_volume': 26320},
#    {'name': '#SaveODAAT',
#     'url': 'http://twitter.com/search?q=%23SaveODAAT',
#     'promoted_content': None,
#     'query': '%23SaveODAAT',
#     'tweet_volume': 662287},
#    {'name': '#UmCaboUmSoldado',
#     'url': 'http://twitter.com/search?q=%23UmCaboUmSoldado',
#     'promoted_content': None,
#     'query': '%23UmCaboUmSoldado',
#     'tweet_volume': 66372},
#    {'name': 'Tomlinson',
#     'url': 'http://twitter.com/search?q=Tomlinson',
#     'promoted_content': None,
#     'query': 'Tomlinson',
#     'tweet_volume': 243301},
#    {'name': '#免許証発行診断',
#     'url': 'http://twitter.com/search?q=%23%E5%85%8D%E8%A8%B1%E8%A8%BC%E7%99%BA%E8%A1%8C%E8%A8%BA%E6%96%AD',
#     'promoted_content': None,
#     'query': '%23%E5%85%8D%E8%A8%B1%E8%A8%BC%E7%99%BA%E8%A1%8C%E8%A8%BA%E6%96%AD',
#     'tweet_volume': 11564},
#    {'name': 'Fizzy',
#     'url': 'http://twitter.com/search?q=Fizzy',
#     'promoted_content': None,
#     'query': 'Fizzy',
#     'tweet_volume': 155633},
#    {'name': 'Valentim',
#     'url': 'http://twitter.com/search?q=Valentim',
#     'promoted_content': None,
#     'query': 'Valentim',
#     'tweet_volume': None},
#    {'name': 'Frank Howard',
#     'url': 'http://twitter.com/search?q=%22Frank+Howard%22',
#     'promoted_content': None,
#     'query': '%22Frank+Howard%22',
#     'tweet_volume': None},
#    {'name': 'Josefa',
#     'url': 'http://twitter.com/search?q=Josefa',
#     'promoted_content': None,
#     'query': 'Josefa',
#     'tweet_volume': None},
#    {'name': 'Avaí',
#     'url': 'http://twitter.com/search?q=Ava%C3%AD',
#     'promoted_content': None,
#     'query': 'Ava%C3%AD',
#     'tweet_volume': None},
#    {'name': 'Grayson Allen',
#     'url': 'http://twitter.com/search?q=%22Grayson+Allen%22',
#     'promoted_content': None,
#     'query': '%22Grayson+Allen%22',
#     'tweet_volume': None},
#    {'name': 'Betina',
#     'url': 'http://twitter.com/search?q=Betina',
#     'promoted_content': None,
#     'query': 'Betina',
#     'tweet_volume': 40701},
#    {'name': 'Oscar Pérez',
#     'url': 'http://twitter.com/search?q=%22Oscar+P%C3%A9rez%22',
#     'promoted_content': None,
#     'query': '%22Oscar+P%C3%A9rez%22',
#     'tweet_volume': 59533},
#    {'name': 'Jake Phelps',
#     'url': 'http://twitter.com/search?q=%22Jake+Phelps%22',
#     'promoted_content': None,
#     'query': '%22Jake+Phelps%22',
#     'tweet_volume': None},
#    {'name': 'Felicite',
#     'url': 'http://twitter.com/search?q=Felicite',
#     'promoted_content': None,
#     'query': 'Felicite',
#     'tweet_volume': 96130},
#    {'name': 'Félicité',
#     'url': 'http://twitter.com/search?q=F%C3%A9licit%C3%A9',
#     'promoted_content': None,
#     'query': 'F%C3%A9licit%C3%A9',
#     'tweet_volume': 96129},
#    {'name': 'Danilo Barcelos',
#     'url': 'http://twitter.com/search?q=%22Danilo+Barcelos%22',
#     'promoted_content': None,
#     'query': '%22Danilo+Barcelos%22',
#     'tweet_volume': None},
#    {'name': 'Gilmar Mendes',
#     'url': 'http://twitter.com/search?q=%22Gilmar+Mendes%22',
#     'promoted_content': None,
#     'query': '%22Gilmar+Mendes%22',
#     'tweet_volume': 63480},
#    {'name': '#GHDÚOGala11',
#     'url': 'http://twitter.com/search?q=%23GHD%C3%9AOGala11',
#     'promoted_content': None,
#     'query': '%23GHD%C3%9AOGala11',
#     'tweet_volume': 132195},
#    {'name': '#ClimateStrike',
#     'url': 'http://twitter.com/search?q=%23ClimateStrike',
#     'promoted_content': None,
#     'query': '%23ClimateStrike',
#     'tweet_volume': 80684},
#    {'name': '#F1noSporTV',
#     'url': 'http://twitter.com/search?q=%23F1noSporTV',
#     'promoted_content': None,
#     'query': '%23F1noSporTV',
#     'tweet_volume': None},
#    {'name': '#DallagnolNaCadeia',
#     'url': 'http://twitter.com/search?q=%23DallagnolNaCadeia',
#     'promoted_content': None,
#     'query': '%23DallagnolNaCadeia',
#     'tweet_volume': 26670},
#    {'name': '#iHeartRadioAwards2019',
#     'url': 'http://twitter.com/search?q=%23iHeartRadioAwards2019',
#     'promoted_content': None,
#     'query': '%23iHeartRadioAwards2019',
#     'tweet_volume': None},
#    {'name': '#LaIraDelFiscal',
#     'url': 'http://twitter.com/search?q=%23LaIraDelFiscal',
#     'promoted_content': None,
#     'query': '%23LaIraDelFiscal',
#     'tweet_volume': None},
#    {'name': '#Duke',
#     'url': 'http://twitter.com/search?q=%23Duke',
#     'promoted_content': None,
#     'query': '%23Duke',
#     'tweet_volume': None},
#    {'name': '#あなたのお葬式で流れる曲',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E3%81%8A%E8%91%AC%E5%BC%8F%E3%81%A7%E6%B5%81%E3%82%8C%E3%82%8B%E6%9B%B2',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E3%81%8A%E8%91%AC%E5%BC%8F%E3%81%A7%E6%B5%81%E3%82%8C%E3%82%8B%E6%9B%B2',
#     'tweet_volume': None},
#    {'name': '#ProjectRunway',
#     'url': 'http://twitter.com/search?q=%23ProjectRunway',
#     'promoted_content': None,
#     'query': '%23ProjectRunway',
#     'tweet_volume': None},
#    {'name': '#bbcqt',
#     'url': 'http://twitter.com/search?q=%23bbcqt',
#     'promoted_content': None,
#     'query': '%23bbcqt',
#     'tweet_volume': 31579},
#    {'name': '#JuevesIntratable',
#     'url': 'http://twitter.com/search?q=%23JuevesIntratable',
#     'promoted_content': None,
#     'query': '%23JuevesIntratable',
#     'tweet_volume': None},
#    {'name': '#AusGP',
#     'url': 'http://twitter.com/search?q=%23AusGP',
#     'promoted_content': None,
#     'query': '%23AusGP',
#     'tweet_volume': 32964},
#    {'name': '#60DaysIn',
#     'url': 'http://twitter.com/search?q=%2360DaysIn',
#     'promoted_content': None,
#     'query': '%2360DaysIn',
#     'tweet_volume': None},
#    {'name': '#MyCoffeeMugSays',
#     'url': 'http://twitter.com/search?q=%23MyCoffeeMugSays',
#     'promoted_content': None,
#     'query': '%23MyCoffeeMugSays',
#     'tweet_volume': None},
#    {'name': '#JumatBerkah',
#     'url': 'http://twitter.com/search?q=%23JumatBerkah',
#     'promoted_content': None,
#     'query': '%23JumatBerkah',
#     'tweet_volume': 10593},
#    {'name': '#RevocaciónDeMandato',
#     'url': 'http://twitter.com/search?q=%23Revocaci%C3%B3nDeMandato',
#     'promoted_content': None,
#     'query': '%23Revocaci%C3%B3nDeMandato',
#     'tweet_volume': 12057},
#    {'name': '#ChauTelefe',
#     'url': 'http://twitter.com/search?q=%23ChauTelefe',
#     'promoted_content': None,
#     'query': '%23ChauTelefe',
#     'tweet_volume': 40852},
#    {'name': '#schoolstrike4climate',
#     'url': 'http://twitter.com/search?q=%23schoolstrike4climate',
#     'promoted_content': None,
#     'query': '%23schoolstrike4climate',
#     'tweet_volume': 26755},
#    {'name': '#TrocaDeEsposas',
#     'url': 'http://twitter.com/search?q=%23TrocaDeEsposas',
#     'promoted_content': None,
#     'query': '%23TrocaDeEsposas',
#     'tweet_volume': None},
#    {'name': '#SallyWalker',
#     'url': 'http://twitter.com/search?q=%23SallyWalker',
#     'promoted_content': None,
#     'query': '%23SallyWalker',
#     'tweet_volume': 20141},
#    {'name': '#PremiosDial',
#     'url': 'http://twitter.com/search?q=%23PremiosDial',
#     'promoted_content': None,
#     'query': '%23PremiosDial',
#     'tweet_volume': 92458},
#    {'name': '#TrunkShowSVU',
#     'url': 'http://twitter.com/search?q=%23TrunkShowSVU',
#     'promoted_content': None,
#     'query': '%23TrunkShowSVU',
#     'tweet_volume': None},
#    {'name': '#MuerteAlComunismoNojoda',
#     'url': 'http://twitter.com/search?q=%23MuerteAlComunismoNojoda',
#     'promoted_content': None,
#     'query': '%23MuerteAlComunismoNojoda',
#     'tweet_volume': None},
#    {'name': '#كلام_يحتاجه_الناس',
#     'url': 'http://twitter.com/search?q=%23%D9%83%D9%84%D8%A7%D9%85_%D9%8A%D8%AD%D8%AA%D8%A7%D8%AC%D9%87_%D8%A7%D9%84%D9%86%D8%A7%D8%B3',
#     'promoted_content': None,
#     'query': '%23%D9%83%D9%84%D8%A7%D9%85_%D9%8A%D8%AD%D8%AA%D8%A7%D8%AC%D9%87_%D8%A7%D9%84%D9%86%D8%A7%D8%B3',
#     'tweet_volume': 14839},
#    {'name': '#SaveOneDayAtATime',
#     'url': 'http://twitter.com/search?q=%23SaveOneDayAtATime',
#     'promoted_content': None,
#     'query': '%23SaveOneDayAtATime',
#     'tweet_volume': None},
#    {'name': '#SKCvCAI',
#     'url': 'http://twitter.com/search?q=%23SKCvCAI',
#     'promoted_content': None,
#     'query': '%23SKCvCAI',
#     'tweet_volume': None},
#    {'name': '#IncertidumbreEconomica',
#     'url': 'http://twitter.com/search?q=%23IncertidumbreEconomica',
#     'promoted_content': None,
#     'query': '%23IncertidumbreEconomica',
#     'tweet_volume': None},
#    {'name': '#InterEintracht',
#     'url': 'http://twitter.com/search?q=%23InterEintracht',
#     'promoted_content': None,
#     'query': '%23InterEintracht',
#     'tweet_volume': 22193},
#    {'name': '#MakeHistoryBy',
#     'url': 'http://twitter.com/search?q=%23MakeHistoryBy',
#     'promoted_content': None,
#     'query': '%23MakeHistoryBy',
#     'tweet_volume': None}],
#   'as_of': '2019-03-15T02:46:32Z',
#   'created_at': '2019-03-15T02:37:45Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
#print(trends[0]['trends'])
#print json.dumps(trends[:2]['trends'],indent=1)
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print(json.dumps(us_trends[:2], indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#DragRace",
#     "url": "http://twitter.com/search?q=%23DragRace",
#     "promoted_content": null,
#     "query": "%23DragRace",
#     "tweet_volume": 12702
#    },
#    {
#     "name": "#iHeartAwards2019",
#     "url": "http://twitter.com/search?q=%23iHeartAwards2019",
#     "promoted_content": null,
#     "query": "%23iHeartAwards2019",
#     "tweet_volume": 363427
#    },
#    {
#     "name": "Zion Williamson",
#     "url": "http://twitter.com/search?q=%22Zion+Williamson%22",
#     "promoted_content": null,
#     "query": "%22Zion+Williamson%22",
#     "tweet_volume": 19099
#    },
#    {
#     "name": "#SaveODAAT",
#     "url": "http://twitter.com/search?q=%23SaveODAAT",
#     "promoted_content": null,
#     "query": "%23SaveODAAT",
#     "tweet_volume": 662287
#    },
#    {
#     "name": "Christchurch",
#     "url": "http://twitter.com/search?q=Christchurch",
#     "promoted_content": null,
#     "query": "Christchurch",
#     "tweet_volume": 26320
#    },
#    {
#     "name": "Frank Howard",
#     "url": "http://twitter.com/search?q=%22Frank+Howard%22",
#     "promoted_content": null,
#     "query": "%22Frank+Howard%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Duke",
#     "url": "http://twitter.com/search?q=%23Duke",
#     "promoted_content": null,
#     "query": "%23Duke",
#     "tweet_volume": null
#    },
#    {
#     "name": "Grayson Allen",
#     "url": "http://twitter.com/search?q=%22Grayson+Allen%22",
#     "promoted_content": null,
#     "query": "%22Grayson+Allen%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#iHeartRadioAwards2019",
#     "url": "http://twitter.com/search?q=%23iHeartRadioAwards2019",
#     "promoted_content": null,
#     "query": "%23iHeartRadioAwards2019",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tomlinson",
#     "url": "http://twitter.com/search?q=Tomlinson",
#     "promoted_content": null,
#     "query": "Tomlinson",
#     "tweet_volume": 243301
#    },
#    {
#     "name": "RIP Jake Phelps",
#     "url": "http://twitter.com/search?q=%22RIP+Jake+Phelps%22",
#     "promoted_content": null,
#     "query": "%22RIP+Jake+Phelps%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cuse",
#     "url": "http://twitter.com/search?q=Cuse",
#     "promoted_content": null,
#     "query": "Cuse",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jay Bilas",
#     "url": "http://twitter.com/search?q=%22Jay+Bilas%22",
#     "promoted_content": null,
#     "query": "%22Jay+Bilas%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lindsey Graham",
#     "url": "http://twitter.com/search?q=%22Lindsey+Graham%22",
#     "promoted_content": null,
#     "query": "%22Lindsey+Graham%22",
#     "tweet_volume": 61857
#    },
#    {
#     "name": "Alicia Keys",
#     "url": "http://twitter.com/search?q=%22Alicia+Keys%22",
#     "promoted_content": null,
#     "query": "%22Alicia+Keys%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wesley Matthews",
#     "url": "http://twitter.com/search?q=%22Wesley+Matthews%22",
#     "promoted_content": null,
#     "query": "%22Wesley+Matthews%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Fizzy",
#     "url": "http://twitter.com/search?q=Fizzy",
#     "promoted_content": null,
#     "query": "Fizzy",
#     "tweet_volume": 155633
#    },
#    {
#     "name": "Lilly Singh",
#     "url": "http://twitter.com/search?q=%22Lilly+Singh%22",
#     "promoted_content": null,
#     "query": "%22Lilly+Singh%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gail Miller",
#     "url": "http://twitter.com/search?q=%22Gail+Miller%22",
#     "promoted_content": null,
#     "query": "%22Gail+Miller%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Gaza",
#     "url": "http://twitter.com/search?q=Gaza",
#     "promoted_content": null,
#     "query": "Gaza",
#     "tweet_volume": 81781
#    },
#    {
#     "name": "ZION IS BACK",
#     "url": "http://twitter.com/search?q=%22ZION+IS+BACK%22",
#     "promoted_content": null,
#     "query": "%22ZION+IS+BACK%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kellyanne Conway",
#     "url": "http://twitter.com/search?q=%22Kellyanne+Conway%22",
#     "promoted_content": null,
#     "query": "%22Kellyanne+Conway%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jordy Nelson",
#     "url": "http://twitter.com/search?q=%22Jordy+Nelson%22",
#     "promoted_content": null,
#     "query": "%22Jordy+Nelson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Artist of the Year",
#     "url": "http://twitter.com/search?q=%22Artist+of+the+Year%22",
#     "promoted_content": null,
#     "query": "%22Artist+of+the+Year%22",
#     "tweet_volume": 10476
#    },
#    {
#     "name": "Rosario Dawson",
#     "url": "http://twitter.com/search?q=%22Rosario+Dawson%22",
#     "promoted_content": null,
#     "query": "%22Rosario+Dawson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Vanjie",
#     "url": "http://twitter.com/search?q=Vanjie",
#     "promoted_content": null,
#     "query": "Vanjie",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tour of the Year",
#     "url": "http://twitter.com/search?q=%22Tour+of+the+Year%22",
#     "promoted_content": null,
#     "query": "%22Tour+of+the+Year%22",
#     "tweet_volume": 15354
#    },
#    {
#     "name": "#Zion",
#     "url": "http://twitter.com/search?q=%23Zion",
#     "promoted_content": null,
#     "query": "%23Zion",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TopChef",
#     "url": "http://twitter.com/search?q=%23TopChef",
#     "promoted_content": null,
#     "query": "%23TopChef",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ProjectRunway",
#     "url": "http://twitter.com/search?q=%23ProjectRunway",
#     "promoted_content": null,
#     "query": "%23ProjectRunway",
#     "tweet_volume": null
#    },
#    {
#     "name": "#60DaysIn",
#     "url": "http://twitter.com/search?q=%2360DaysIn",
#     "promoted_content": null,
#     "query": "%2360DaysIn",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Legacies",
#     "url": "http://twitter.com/search?q=%23Legacies",
#     "promoted_content": null,
#     "query": "%23Legacies",
#     "tweet_volume": 18166
#    },
#    {
#     "name": "#MyCoffeeMugSays",
#     "url": "http://twitter.com/search?q=%23MyCoffeeMugSays",
#     "promoted_content": null,
#     "query": "%23MyCoffeeMugSays",
#     "tweet_volume": null
#    },
#    {
#     "name": "#rupaulsdragrace",
#     "url": "http://twitter.com/search?q=%23rupaulsdragrace",
#     "promoted_content": null,
#     "query": "%23rupaulsdragrace",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SKCvCAI",
#     "url": "http://twitter.com/search?q=%23SKCvCAI",
#     "promoted_content": null,
#     "query": "%23SKCvCAI",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TrunkShowSVU",
#     "url": "http://twitter.com/search?q=%23TrunkShowSVU",
#     "promoted_content": null,
#     "query": "%23TrunkShowSVU",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MakeHistoryBy",
#     "url": "http://twitter.com/search?q=%23MakeHistoryBy",
#     "promoted_content": null,
#     "query": "%23MakeHistoryBy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GUHH",
#     "url": "http://twitter.com/search?q=%23GUHH",
#     "promoted_content": null,
#     "query": "%23GUHH",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SaveOneDayAtATime",
#     "url": "http://twitter.com/search?q=%23SaveOneDayAtATime",
#     "promoted_content": null,
#     "query": "%23SaveOneDayAtATime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HipHopBootCamp",
#     "url": "http://twitter.com/search?q=%23HipHopBootCamp",
#     "promoted_content": null,
#     "query": "%23HipHopBootCamp",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HailWV",
#     "url": "http://twitter.com/search?q=%23HailWV",
#     "promoted_content": null,
#     "query": "%23HailWV",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MarriageBootCampHipHop",
#     "url": "http://twitter.com/search?q=%23MarriageBootCampHipHop",
#     "promoted_content": null,
#     "query": "%23MarriageBootCampHipHop",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WillAndGrace",
#     "url": "http://twitter.com/search?q=%23WillAndGrace",
#     "promoted_content": null,
#     "query": "%23WillAndGrace",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ForThePeopleABC",
#     "url": "http://twitter.com/search?q=%23ForThePeopleABC",
#     "promoted_content": null,
#     "query": "%23ForThePeopleABC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Hearties4S6",
#     "url": "http://twitter.com/search?q=%23Hearties4S6",
#     "promoted_content": null,
#     "query": "%23Hearties4S6",
#     "tweet_volume": 29339
#    },
#    {
#     "name": "#CUE19",
#     "url": "http://twitter.com/search?q=%23CUE19",
#     "promoted_content": null,
#     "query": "%23CUE19",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TBLvsDET",
#     "url": "http://twitter.com/search?q=%23TBLvsDET",
#     "promoted_content": null,
#     "query": "%23TBLvsDET",
#     "tweet_volume": null
#    },
#    {
#     "name": "#iHeartRadio2019",
#     "url": "http://twitter.com/search?q=%23iHeartRadio2019",
#     "promoted_content": null,
#     "query": "%23iHeartRadio2019",
#     "tweet_volume": null
#    },
#    {
#     "name": "#iheartradiomusicawards",
#     "url": "http://twitter.com/search?q=%23iheartradiomusicawards",
#     "promoted_content": null,
#     "query": "%23iheartradiomusicawards",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HereComesDuke",
#     "url": "http://twitter.com/search?q=%23HereComesDuke",
#     "promoted_content": null,
#     "query": "%23HereComesDuke",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-03-15T02:46:32Z",
#   "created_at": "2019-03-15T02:37:45Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
print([(trend['name']) for trend in us_trends[0]['trends'][:5]])
# Out:
# ['#DragRace', '#iHeartAwards2019', 'Zion Williamson', '#SaveODAAT', 'Christchurch']

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #iHeartRadioAwards2019,Frank Howard,#TrocaDeEsposas,#DallagnolNaCadeia,#JumatBerkah,#SKCvCAI,Fizzy,#ProjectRunway,Danilo Barcelos,#كلام_يحتاجه_الناس,#SaveODAAT,#iHeartAwards2019,Valentim,#LaIraDelFiscal,Avaí,#Duke,#免許証発行診断,#ClimateStrike,#MakeHistoryBy,Oscar Pérez,#IncertidumbreEconomica,#あなたのお葬式で流れる曲,#bbcqt,#60DaysIn,#SallyWalker,Tomlinson,#RevocaciónDeMandato,#F1noSporTV,#GHDÚOGala11,#ChauTelefe,Zion,#MuerteAlComunismoNojoda,Gilmar Mendes,#schoolstrike4climate,#SaveOneDayAtATime,#TrunkShowSVU,#InterEintracht,#JuevesIntratable,#AusGP,Betina,Christchurch,#LaLlamada,Felicite,#PremiosDial,Jake Phelps,Josefa,#UmCaboUmSoldado,Félicité,#MyCoffeeMugSays,Grayson Allen
# ('----------', 'us')
# #iHeartRadioAwards2019,Frank Howard,Jordy Nelson,#SKCvCAI,#GUHH,Fizzy,#ProjectRunway,#SaveODAAT,#MarriageBootCampHipHop,RIP Jake Phelps,#iHeartAwards2019,#TopChef,#HailWV,#WillAndGrace,Lilly Singh,#Duke,Cuse,#Zion,#iheartradiomusicawards,Kellyanne Conway,#HereComesDuke,Gaza,Vanjie,#MakeHistoryBy,Tour of the Year,Zion Williamson,#HipHopBootCamp,#60DaysIn,Alicia Keys,Lindsey Graham,Jay Bilas,Artist of the Year,Tomlinson,Rosario Dawson,Gail Miller,#rupaulsdragrace,#Hearties4S6,ZION IS BACK,#SaveOneDayAtATime,#TrunkShowSVU,#DragRace,#CUE19,Wesley Matthews,Christchurch,#ForThePeopleABC,#TBLvsDET,#Legacies,#iHeartRadio2019,#MyCoffeeMugSays,Grayson Allen
# ('----------', 'san diego')
# #iHeartRadioAwards2019,Frank Howard,Jordy Nelson,#SKCvCAI,#GUHH,Fizzy,#AvengersEndgame,#ProjectRunway,#SaveODAAT,#MarriageBootCampHipHop,RIP Jake Phelps,#iHeartAwards2019,#instagramdown,Pi Day,#TopChef,#HailWV,#WillAndGrace,Lilly Singh,#Duke,Cuse,#Zion,Kellyanne Conway,Gaza,#MakeHistoryBy,UNLV,Zion Williamson,#HipHopBootCamp,#60DaysIn,Alicia Keys,#FacebookDown,Jay Bilas,Lindsey Graham,Artist of the Year,Tomlinson,Gail Miller,#rupaulsdragrace,#Hearties4S6,ZION IS BACK,#SaveOneDayAtATime,#TrunkShowSVU,#DragRace,#PiDay,Wesley Matthews,Beto,Christchurch,#ForThePeopleABC,#TBLvsDET,#Legacies,#MyCoffeeMugSays,Grayson Allen

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#60DaysIn', '#iHeartAwards2019', '#iHeartRadioAwards2019', 'Frank Howard', '#SaveOneDayAtATime', 'Tomlinson', '#SKCvCAI', '#Duke', 'Christchurch', 'Fizzy', '#MyCoffeeMugSays', 'Grayson Allen', '#ProjectRunway', '#MakeHistoryBy', '#TrunkShowSVU', '#SaveODAAT'}
# ('==========', 'intersection of us and san-diego')
# {'#iHeartRadioAwards2019', 'Frank Howard', 'Jordy Nelson', '#SKCvCAI', '#GUHH', 'Fizzy', '#ProjectRunway', '#SaveODAAT', '#MarriageBootCampHipHop', 'RIP Jake Phelps', '#iHeartAwards2019', '#TopChef', '#HailWV', '#WillAndGrace', 'Lilly Singh', '#Duke', 'Cuse', '#Zion', 'Kellyanne Conway', 'Gaza', '#MakeHistoryBy', 'Zion Williamson', '#HipHopBootCamp', '#60DaysIn', 'Alicia Keys', 'Lindsey Graham', 'Jay Bilas', 'Artist of the Year', 'Tomlinson', 'Gail Miller', '#rupaulsdragrace', '#Hearties4S6', 'ZION IS BACK', '#SaveOneDayAtATime', '#TrunkShowSVU', '#DragRace', 'Wesley Matthews', 'Christchurch', '#ForThePeopleABC', '#TBLvsDET', '#Legacies', '#MyCoffeeMugSays', 'Grayson Allen'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#EndangeredSpeciesDay' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)
# Out:
# [{'created_at': 'Fri Mar 15 01:37:18 +0000 2019', 'id': 1106368744484306944, 'id_str': '1106368744484306944', 'text': 'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/34FKEy9Ffc', 'truncated': True, 'entities': {'hashtags': [{'text': 'EndangeredSpeciesDay', 'indices': [84, 105]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/34FKEy9Ffc', 'expanded_url': 'https://twitter.com/i/web/status/1106368744484306944', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [108, 131]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1966884739, 'id_str': '1966884739', 'name': 'Barbara Steinberg', 'screen_name': 'h2ocolorbarbara', 'location': '', 'description': 'artist and art teacher for Animal Kindness Club art classes. for children and adults', 'url': 'https://t.co/K2tYG39kz0', 'entities': {'url': {'urls': [{'url': 'https://t.co/K2tYG39kz0', 'expanded_url': 'http://www.barbarasteinbergart.com', 'display_url': 'barbarasteinbergart.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 167, 'friends_count': 951, 'listed_count': 3, 'created_at': 'Thu Oct 17 13:34:55 +0000 2013', 'favourites_count': 7747, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 7269, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/916765509286162432/hAyWZNZx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/916765509286162432/hAyWZNZx_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, {'created_at': 'Thu Mar 14 14:27:38 +0000 2019', 'id': 1106200216921915395, 'id_str': '1106200216921915395', 'text': 'RT @RobertIrwin: We are experiencing the 6th mass extinction on earth and our precious wildlife is disappearing faster than ever. \nThis #En…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RobertIrwin', 'name': 'Robert Irwin', 'id': 14949475, 'id_str': '14949475', 'indices': [3, 15]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 36106220, 'id_str': '36106220', 'name': 'Moira E Fay', 'screen_name': 'mefay', 'location': 'Cranston, RI', 'description': "If I can help open just 1 set of eyes 2 need 2 rescue animals, adopt not shop, climate change, clean water & air, civility & respect for others I'll be content", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 138, 'friends_count': 406, 'li ...

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 23

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/34FKEy9Ffc',
#  'RT @RobertIrwin: We are experiencing the 6th mass extinction on earth and our precious wildlife is disappearing faster than ever. \nThis #En…',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/i1S0DQMFhh',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/aHp8V3JBOD',
#  'Add your name to my petition to my mayor, @MayorKeller asking him to designate May 17th, 2019 as… https://t.co/eG6Ep5aTGH',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/5orq2SgQ6o',
#  'RT @BearmanShannon: Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay: https://t.co…',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/iDq2mEtGRD',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'Have you read our March newsletter? This month we share resources and action items related to our… https://t.co/nZgUHzOS4s',
#  'RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay…',
#  'RT @BearmanShannon: Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay: https://t.co…',
#  'RT @BearmanShannon: Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay: https://t.co…',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/QmhOd3y2ne',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/lAE7cUeEEF',
#  'Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:… https://t.co/ILuo6yn7FV',
#  'Start or sign a petition to your mayor or other local official asking that they designate May 17th as… https://t.co/QDQI2MMjzI',
#  'RT @LEAPyeg: #EndangeredSpeciesDay fits! 40 yrs ago today Lucy has been in captivity. Watch global advocates speak out for her https://t.co…',
#  '#photomarchchallenge \n\nhari ke-11, Pavo muticus, Batu Secret Zoo, Malang, Jawa Timur, Indonesia\n\n#photography… https://t.co/7qdSpgM2X6',
#  'RT @LEAPyeg: #EndangeredSpeciesDay fits! 40 yrs ago today Lucy has been in captivity. Watch global advocates speak out for her https://t.co…',
#  "RT @EllieandEdmond: It's Endangered Species Day &amp; @sdzglobal is having a rally for rhinos!! #Rally4Rhinos #endangeredspeciesday http://t.co…",
#  'RT @EllenPompeo: Stop killing RHINOS #rally4rhinos #EndangeredSpeciesDay @sdzglobal',
#  'Our #EndangeredSpeciesDay #artcontest makes the list! Still going strong in 2019, K-12 entries are being accepted t… https://t.co/8veEhpRhmu',
#  'Celebrate #EndangeredSpeciesDay (May 17) and the #InternationalYearoftheSalmon by having your child or class partic… https://t.co/YseHict0wf',
#  'Endangered Species Day Bulletin Insert Resource and planning toolkit is now available for download! Endangered Spec… https://t.co/P4M3aOycax',
#  'RT @ChildrenNature: #EndangeredSpeciesDay (this year on 5/17) is an opportunity for people of all ages, especially kids, to learn about the…',
#  '#EndangeredSpeciesDay (this year on 5/17) is an opportunity for people of all ages, especially kids, to learn about… https://t.co/jgPDpgM85y']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Fri Mar 15 01:37:18 +0000 2019",
#  "id": 1106368744484306944,
#  "id_str": "1106368744484306944",
#  "text": "Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:\u2026 https://t.co/34FKEy9Ffc",
#  "truncated": true,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "EndangeredSpeciesDay",
#     "indices": [
#      84,
#      105
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/34FKEy9Ffc",
#     "expanded_url": "https://twitter.com/i/web/status/1106368744484306944",
#     "display_url": "twitter.com/i/web/status/1\u2026",
#     "indices": [
#      108,
#      131
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1966884739,
#   "id_str": "1966884739",
#   "name": "Barbara Steinberg",
#   "screen_name": "h2ocolorbarbara",
#   "location": "",
#   "description": "artist and art teacher for Animal Kindness Club art classes. for children and adults",
#   "url": "https://t.co/K2tYG39kz0",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/K2tYG39kz0",
#       "expanded_url": "http://www.barbarasteinbergart.com",
#       "display_url": "barbarasteinbergart.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 167,
#   "friends_count": 951,
#   "listed_count": 3,
#   "created_at": "Thu Oct 17 13:34:55 +0000 2013",
#   "favourites_count": 7747,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 7269,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/916765509286162432/hAyWZNZx_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/916765509286162432/hAyWZNZx_normal.jpg",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 105
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:\u2026 https://t.co/34FKEy9Ffc",
#  "RT @RobertIrwin: We are experiencing the 6th mass extinction on earth and our precious wildlife is disappearing faster than ever. \nThis #En\u2026",
#  "RT @endangered: Start or sign a petition to your mayor or other local official asking that they designate May 17th as #EndangeredSpeciesDay\u2026",
#  "Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:\u2026 https://t.co/i1S0DQMFhh",
#  "Add your name to my petition to my mayor asking them to designate May 17th, 2019 as #EndangeredSpeciesDay:\u2026 https://t.co/aHp8V3JBOD"
# ]
# [
#  "RobertIrwin",
#  "endangered",
#  "MayorKeller",
#  "BearmanShannon",
#  "LEAPyeg"
# ]
# [
#  "EndangeredSpeciesDay",
#  "EndangeredSpeciesDay",
#  "EndangeredSpeciesDay",
#  "EndangeredSpeciesDay",
#  "EndangeredSpeciesDay"
# ]
# [
#  "Add",
#  "your",
#  "name",
#  "to",
#  "my"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('to', 35), ('my', 20), ('your', 13), ('petition', 12), ('asking', 12), ('designate', 12), ('May', 12), ('mayor', 11), ('Add', 10), ('name', 10)]
#
# [('sdzglobal', 2), ('RobertIrwin', 1), ('endangered', 1), ('MayorKeller', 1), ('BearmanShannon', 1), ('LEAPyeg', 1), ('EllieandEdmond', 1), ('EllenPompeo', 1), ('ChildrenNature', 1)]
#
# [('EndangeredSpeciesDay', 16), ('photomarchchallenge', 1), ('photography', 1), ('Rally4Rhinos', 1), ('endangeredspeciesday', 1), ('rally4rhinos', 1), ('artcontest', 1), ('InternationalYearoftheSalmon', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# to                   |     35
# my                   |     20
# your                 |     13
# petition             |     12
# asking               |     12
# designate            |     12
# May                  |     12
# mayor                |     11
# Add                  |     10
# name                 |     10
#
#     Screen Name      | Count
# ****************************************
# sdzglobal            |      2
# RobertIrwin          |      1
# endangered           |      1
# MayorKeller          |      1
# BearmanShannon       |      1
# LEAPyeg              |      1
# EllieandEdmond       |      1
# EllenPompeo          |      1
# ChildrenNature       |      1
#
#       Hashtag        | Count
# ****************************************
# EndangeredSpeciesDay |     16
# photomarchchallenge  |      1
# photography          |      1
# Rally4Rhinos         |      1
# endangeredspeciesday |      1
# rally4rhinos         |      1
# artcontest           |      1
# InternationalYearoftheSalmon |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 35:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  5953   |    MTVAwards    | RT @MTVAwards: OH HEYY LITTLE MONSTERS 👋👋👋\The QUE
#         |                 | EN @LadyGaga won Best Music Documentary for ‘Gaga:
#         |                 |  Five Foot Two.’ | Tune into #MTVAwards…
#  1887   |       MTV       | RT @MTV: Someone please photoshop me (and @dylanmi
#         |                 | nnette) into these adorable photos of the @13Reaso
#         |                 | nsWhy cast. See these babes at the #MTV…
#  1729   |  SoyLaloCastro  | RT @SoyLaloCastro: El mejor momento de la noche, e
#         |                 | l cast de 13RW entregando premio a los chicos de S
#         |                 | tranger Things #MTVAwards https://t.co/…
#   150   |    NaizerCC     | RT @NaizerCC: 'Hey Ma' en los #MTVAwards \Como sup
#         |                 | erar a Camila en esta presentación!?!\#PREMIOSMTVM
#         |                 | IAW #MTVINSTAGLCABELLO \https://t.co/iU…
#   105   |    MTVAwards    | RT @MTVAwards: blessing your feed with @Zendaya SE
#         |                 | RV👏ING👏 on the #MTVAwards red carpet ✨ #TBT https:
#         |                 | //t.co/e0a0KQwMVf
#   80    |  angelwolfinn   | RT @angelwolfinn: MEU IT GANHOU FINALMENTE EU POSS
#         |                 | O GRITAR PRO MUNDO OUVIR É CAMPEÃOOOOOO #MTVAwards
#         |                 |  https://t.co/9NDTBoOeto
#   64    |    MTVAwards    | RT @MTVAwards: For #InternationalWomensDay, we're
#         |                 | celebrating by reliving the ✨inspirational✨speeche
#         |                 | s of the Trailblazer honorees at the #M…
#   48    |       MTV       | RT @MTV: For #InternationalWomensDay, we're celebr
#         |                 | ating by reliving the incredibly inspirational spe
#         |                 | eches of the Trailblazer honorees at th…
#   47    |  bestofpratts   | RT @bestofpratts: Ladies and gentlemen: Here is ou
#         |                 | r Generation Award recipient. #MTVAwards https://t
#         |                 | .co/gTovUGNmgm
#   19    |  jackgrazerbr   | RT @jackgrazerbr: 📸| Jack no Red Carpet do #MTVAwa
#         |                 | rds #2 https://t.co/5sGDiG7Iin
